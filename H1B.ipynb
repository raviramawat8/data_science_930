# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('f:/Data/Project/h1b.csv',index_col=0)
# Out:
# C:\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 1  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 2  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 3  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 4  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 5            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 1  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 2               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 3               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 4               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 5               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# ...

# %%
df.drop(['lon','lat'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 1  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 2  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 3  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 4  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 5            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 1  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 2               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 3               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 4               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 5               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE
# ...

# %%
df.columns=['status','company','post','job','full_time','salary','year','place']

# %%
df
# Out:
#                       status  \
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4        CERTIFIED-WITHDRAWN
# 5                  WITHDRAWN
# ...                      ...
# 3002454                  NaN
# 3002455                  NaN
# 3002456                  NaN
# 3002457                  NaN
# 3002458                  NaN
#
#                                                    company  \
# 1                                   UNIVERSITY OF MICHIGAN
# 2                                   GOODMAN NETWORKS, INC.
# 3                                PORTS AMERICA GROUP, INC.
# 4        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 5                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002454                                                NaN
# 3002455                                                NaN
# 3002456                                                NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df['status'].unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %%
df[df['status']=='REJECTED']
# Out:
#            status                     company  \
# 1605560  REJECTED  SUPREME TECH SOLUTIONS LLC
# 1728392  REJECTED      ACCESS THERAPIES, INC.
#
#                                       post                  job full_time  \
# 1605560  Software Developers, Applications     SOFTWARE ANALYST         Y
# 1728392                Physical Therapists  PHYSICAL THERAPISTS         Y
#
#           salary    year                  place
# 1605560  57886.0  2014.0  WEST DES MOINES, IOWA
# 1728392  53248.0  2014.0     VINCENNES, INDIANA

# %%
df['company'].value_counts()[:15].plot(kind='pie',autopct='%.2f')
plt.show()

# %%
d=df[df['company']=="TATA CONSULTANCY SERVICES LIMITED"]

# %%
p=d['status'].value_counts()

# %%
p.plot(kind='bar',ec='k')

# %%
df[df['status']=="DENIED"]
# Out:
#          status                         company  \
# 40       DENIED                 PARALLELS, INC.
# 48       DENIED            RANCHO LA PUERTA LLC
# 92       DENIED                  EAGLE MINE LLC
# 96       DENIED             BAKER & MCKENZIE PC
# 99       DENIED   MANITOWOC FSG OPERATIONS, LLC
# ...         ...                             ...
# 3002370  DENIED                  CUSTOMTBT, LLC
# 3002379  DENIED    KEVIN PARK & ASSOCIATES, LTD
# 3002384  DENIED            IVERTIX INCORPORATED
# 3002390  DENIED       PROGRESSIVE SURFACE, INC.
# 3002393  DENIED  PEI PARTNERSHIP ARCHITECTS LLP
#
#                                      post  \
# 40                       CHIEF EXECUTIVES
# 48                       CHIEF EXECUTIVES
# 92                       CHIEF EXECUTIVES
# 96                       CHIEF EXECUTIVES
# 99                       CHIEF EXECUTIVES
# ...                                   ...
# 3002370        Instructional Coordinators
# ...

# %%
type(df['salary'][1])
# Out:
# numpy.float64

# %%
d = df.copy()

# %%
d[d['company']=="INFOSYS LIMITED"].sort_values(by='salary',ascending=False)[:5]
# Out:
#          status          company                               post  \
# 2250525  DENIED  INFOSYS LIMITED  Software Developers, Applications
# 2310037  DENIED  INFOSYS LIMITED   Computer Occupations, All Other*
# 2279214  DENIED  INFOSYS LIMITED   Computer Occupations, All Other*
# 2228662  DENIED  INFOSYS LIMITED          Computer Systems Analysts
# 2282316  DENIED  INFOSYS LIMITED          Computer Systems Analysts
#
#                 job full_time       salary    year                      place
# 2250525        LEAD         Y  190188960.0  2012.0           ATLANTA, GEORGIA
# 2310037     MANAGER         Y  189668960.0  2012.0     MINNEAPOLIS, MINNESOTA
# 2279214   ARCHITECT         Y  184132000.0  2012.0  CHARLOTTE, NORTH CAROLINA
# 2228662        LEAD         Y  175090240.0  2012.0           ATLANTA, GEORGIA
# 2282316  CONSULTANT         Y  167864320.0  2012.0              AUSTIN, TEXAS

# %%
u=d.sort_values(by='salary',ascending=False)[:5]

# %%
fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(111)
ax.bar(np.arange(len(u['salary'])),u['salary'])
ax.set_xticklabels(u['salary'],rotation=80)
# Out:
# [Text(0, 0, '6997606720.0'),
#  Text(0, 0, '1007814080.0'),
#  Text(0, 0, '820132347.0'),
#  Text(0, 0, '709999949.0'),
#  Text(0, 0, '657900000.0')]

# %%
u['company']
# Out:
# 2163249    GUARDIAN HEALTHCARE PROVIDERS, INC.
# 2797983                       SCIVANTAGE, INC.
# 1673868                 DISCOVER PRODUCTS INC.
# 1819719                          IDEXCEL, INC.
# 2775907                    COMMONHEALTH ACTION
# Name: company, dtype: object
